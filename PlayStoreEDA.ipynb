# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('googleplaystore.csv')
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# summary
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# missing value check
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# The dataset has 10841 rows and 13 columns
#
# It has missing values :
#
# Rating: 1474 missing values
#
# Type: 1 missing value
#
# Content Rating: 1 missing value
#
# Current Ver: 8 missing values
#
# Android Ver: 3 missing value

# %% [markdown]
# **#### Data Cleaning**

# %%
df['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
df['Reviews'] = df['Reviews'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-353/1257523331.py in <cell line: 0>()
# ----> 1 df['Reviews'] = df['Reviews'].astype('int')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
#The Row with 3.0M value
df[df['Reviews'].str.contains('M', na=False)]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df['Reviews'] = df['Reviews'].str.replace('M', '').astype('float')

# %%
df['Reviews'].dtype
# Out:
# dtype('float64')

# %%
df['Reviews'] = df['Reviews'].astype('int')
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews Size  Installs  Type Price Content Rating  \
# 0      159  19M   10,000+  Free     0       Everyone
# 1      967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
df['Size'] = df['Size'].str.replace('M', '000')
df['Size'] = df['Size'].str.replace('k', '')
df['Size'] = df['Size'].str.replace('1,000+', '1000')
df['Size'] = df['Size'].replace('Varies with device', np.nan)

df['Size'] = df['Size'].astype('float')

# %%
df['Size'].isnull().sum()
# Out:
# np.int64(1695)

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
# Removing the unwanted characters
chars_to_remove = ['+', ',', '$']
cols_to_clean = ['Installs', 'Price']
for item in chars_to_remove:
  for cols in cols_to_clean:
    df[cols] = df[cols].str.replace(item, '')

# %%
df['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        'Everyone', '1.20', '1.04'], dtype=object)

# %%
df['Installs'].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0', 'Free'],
#       dtype=object)

# %%
 df[df['Installs'].str.contains('Free')]
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0        3
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1000.0     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
#Drop the row with misplaced values
df.drop(index=10472, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.2+ MB

# %%
df['Installs'] = df['Installs'].astype('int')
df['Price'] = df['Price'].astype('float')

# %%
df['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
df['Last Updated'] = pd.to_datetime(df['Last Updated'])
df['Day'] = df['Last Updated'].dt.day
df['Month'] = df['Last Updated'].dt.month
df['Year'] = df['Last Updated'].dt.year

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...

# %%
df['Current Ver'].unique()
# Out:
# array(['1.0.0', '2.0.0', '1.2.4', ..., '1.0.612928', '0.3.4', '2.0.148.0'],
#       dtype=object)

# %%
df['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  Day             10840 non-null  int32
#  14  Month           10840 non-null  int32
#  15  Year            10840 non-null  int32
# ...

# %%
df[df['App'].duplicated()].shape
# Out:
# (1181, 16)

# %%
#drop duplicated records
df = df.drop_duplicates(subset=['App'], keep='first')

# %%
df.shape
# Out:
# (9659, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   datetime64[ns]
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     9657 non-null   object
#  13  Day             9659 non-null   int32
#  14  Month           9659 non-null   int32
#  15  Year            9659 non-null   int32
# ...

# %%
df['Rating'].fillna(df['Rating'].median(), inplace=True)

# %% [markdown]
# # **EDA**

# %%
# get the number of apps for each category
sns.set_style('darkgrid')
plt.figure(figsize=(10, 5))
ax=sns.countplot(x='Category', data=df,palette='Set1')
plt.title('Number of Apps Per Category')
plt.xticks(rotation=90)
plt.ylabel('Number of Apps')
plt.show()

# %%
# get the number of installs for each category
install_category =(df.groupby(['Category'])['Installs']
                   .sum()
                   .reset_index()
                   .sort_values(by='Installs', ascending=False)
                   .head(10))


plt.figure(figsize=(16,5), facecolor='lightgrey')
sd = sns.barplot(x='Category',
            y='Installs',
            data=install_category,
            hue='Category',
            palette='Set1')
plt.title('Number of Installs For Each Category')
plt.xticks(rotation=90)
#sd.grid(True, axis='y', linestyle='--', alpha=0.7)
sd.set_facecolor('#e6f2ff')
plt.tight_layout()

# %% [markdown]
# Ratings :-

# %%
# show the distribution of rating
plt.figure(figsize=(14, 5))
sns.countplot(x='Rating',
              data=df,
              palette='Set1')
plt.title('Rating Distribution')
plt.xticks(rotation=90)
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# From this distribution plotting, it implies that most of the apps in the Play Store are having rating higher than 4 or in the range of 4 to 4.7.

# %% [markdown]
# **What are the Top 5 most installed Apps in Each popular Categories ??**

# %%
most_installed = (df.groupby(['Category', 'App'])['Installs']
                  .sum()
                  .reset_index()
                  .sort_values(by='Installs', ascending=False)
                  .head(5)
)
import matplotlib.pyplot as plt
import seaborn as sns

# 2x2 layout
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Top 5 Categories by Total Installs
top_categories = (df.groupby('Category')['Installs']
                  .sum()
                  .sort_values(ascending=False)
                  .head(5)
                  .reset_index())

sns.barplot(data=top_categories,
            x='Installs',
            y='Category',
            palette='Set1',
            ax=axes[0, 0])
axes[0, 0].set_title("Top 5 Categories by Installs")


# Number of Apps per Category
sns.countplot(data=df,
              y='Category',
              order=df['Category'].value_counts().index[:5],
              palette='Set1',
              ax=axes[0, 1])
axes[0, 1].set_title("Top 5 Categories by App Count")


# Average Rating per Category
avg_rating = (df.groupby('Category')['Rating']
              .mean()
              .sort_values(ascending=False)
              .head(5)
              .reset_index())

sns.barplot(data=avg_rating,
            x='Rating',
            y='Category',
            palette='Set1',
            ax=axes[1, 0])
axes[1, 0].set_title("Top 5 Categories by Average Rating")


# Free vs Paid Apps
sns.countplot(data=df,
              x='Type',
              palette='Set1',
              ax=axes[1, 1])
axes[1, 1].set_title("Free vs Paid Apps")

plt.tight_layout()
plt.show()

# %% [markdown]
# Insight:
#
# GAME category usually has the highest installs.
#
# This means people download games more compared to other types of apps.
#
# Categories like COMMUNICATION and SOCIAL also have very high installs.
#
# So entertainment + social interaction apps dominate the Play Store.

# %%
# 1. What is the top 5 apps on the basis of installs?
df_copy = df.sort_values(by='Installs', ascending=False)
df_copy.head(5)
# Out:
#                     App             Category  Rating   Reviews     Size  \
# 3736        Google News   NEWS_AND_MAGAZINES     3.9    877635  13000.0
# 2554            Google+               SOCIAL     4.2   4831125      NaN
# 1654     Subway Surfers                 GAME     4.5  27722264  76000.0
# 152   Google Play Books  BOOKS_AND_REFERENCE     3.9   1433233      NaN
# 3665            YouTube        VIDEO_PLAYERS     4.3  25655305      NaN
#
#         Installs  Type  Price Content Rating                   Genres  \
# 3736  1000000000  Free    0.0           Teen         News & Magazines
# 2554  1000000000  Free    0.0           Teen                   Social
# 1654  1000000000  Free    0.0   Everyone 10+                   Arcade
# 152   1000000000  Free    0.0           Teen        Books & Reference
# 3665  1000000000  Free    0.0           Teen  Video Players & Editors
#
#      Last Updated         Current Ver         Android Ver  Day  Month  Year
# ...

# %%
# 2. What is the top 5 reviewed apps?
df_copy = (df.groupby(by=['App', 'Category', 'Rating'])[['Reviews']]
      .sum()
      .reset_index()
      .sort_values(by=['Reviews'], ascending=False))
df_copy.head(5)
# Out:
#                                            App       Category  Rating  \
# 4328                                  Facebook         SOCIAL     4.1
# 9041                        WhatsApp Messenger  COMMUNICATION     4.4
# 5399                                 Instagram         SOCIAL     4.5
# 6165  Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 2564                            Clash of Clans           GAME     4.6
#
#        Reviews
# 4328  78158306
# 9041  69119316
# 5399  66577313
# 6165  56642847
# 2564  44891723

# %%
# 3. What is the top 5 expensive apps?
df_copy = df.sort_values(by=['Price'], ascending=False)
df_copy.head(5)
# Out:
#                            App   Category  Rating  Reviews     Size  Installs  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE     3.6      275      7.3     10000
# 5354            I am Rich Plus     FAMILY     4.0      856      8.7     10000
# 5373        I AM RICH PRO PLUS    FINANCE     4.0       36  41000.0      1000
# 4197    most expensive app (H)     FAMILY     4.3        6      1.5       100
# 5369                 I am Rich    FINANCE     4.3      180      3.8      5000
#
#       Type   Price Content Rating         Genres Last Updated Current Ver  \
# 4367  Paid  400.00       Everyone      Lifestyle   2018-05-03       1.0.1
# 5354  Paid  399.99       Everyone  Entertainment   2018-05-19         3.0
# 5373  Paid  399.99       Everyone        Finance   2018-06-25       1.0.2
# 4197  Paid  399.99       Everyone  Entertainment   2018-07-16         1.0
# 5369  Paid  399.99       Everyone        Finance   2018-03-22         1.0
#
#      Android Ver  Day  Month  Year
# ...

# %%
# 4. What is the top 3 most installed apps in Game category?
df_copy = df[df['Category'] == 'GAME']
df_copy = df.sort_values(by=['Installs'], ascending=False)
df.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver  Day  \
# 0               Art & Design   2018-01-07       1.0.0  4.0.3 and up    7
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0  4.0.3 and up   15
# 2               Art & Design   2018-08-01       1.2.4  4.0.3 and up    1
#
#    Month  Year
# 0      1  2018
# 1      1  2018
# 2      8  2018

# %%
# 5. Which 5 apps from the 'FAMILY' category are having the lowest rating?
df_copy = df[df['Category'] == 'FAMILY']
df_copy = df.sort_values(by=['Rating'], ascending=True)
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...
